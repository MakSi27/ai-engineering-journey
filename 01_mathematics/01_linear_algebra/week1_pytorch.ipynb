# %%
import torch

# %%
# creating a tensor is exactly like numpy
matrix1 = torch.tensor([[1,2],[3,4]])
matrix2 = torch.tensor([[5,6],[7,8]])
# shape
print(matrix1.shape)
print(matrix2.shape)
# Out:
# torch.Size([2, 2])
# torch.Size([2, 2])

# %%
print(torch.matmul(matrix1, matrix2))
# Out:
# tensor([[19, 22],
#         [43, 50]])
